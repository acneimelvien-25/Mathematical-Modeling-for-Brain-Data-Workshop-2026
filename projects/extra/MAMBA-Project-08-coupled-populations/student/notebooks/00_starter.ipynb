# %% [markdown]
# # Project 08 — Starter Notebook
#
# **Task:** Given the activity of 5 coupled nodes at several coupling strengths w, measure how the amplitude of activity grows as w approaches a critical value.
#
# Fill in each section below. All required imports are already in the setup cell.

# %% [markdown]
# ## 0. Setup

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

DATA = Path("../../shared/data")

# %% [markdown]
# ## Step 1. Load fit_timeseries.csv, print the unique w values.

# %%
# TODO: your code here

# %% [markdown]
# ## Step 2. Plot the 5 nodes' activity for one w value.

# %%
# TODO: your code here

# %% [markdown]
# ## Step 3. For each w, compute mean amplitude (std) across the 5 nodes.

# %%
# TODO: your code here

# %% [markdown]
# ## Step 4. Plot amplitude vs w for both fit and holdout data.

# %%
# TODO: your code here

# %% [markdown]
# ## Interpretation (3-4 sentences)
#
# *(Write your paragraph here — what did you find? What worked, what did not?)*
