# %% [markdown]
# # Project 04 — Starter Notebook
#
# **Task:** You have voltage recordings from 6 sessions with irregular sample times. Estimate the mean voltage V_ss for each session and check how the estimate depends on how densely each session was sampled.
#
# Fill in each section below. All required imports are already in the setup cell.

# %% [markdown]
# ## 0. Setup

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

DATA = Path("../../shared/data")

# %% [markdown]
# ## Step 1. Load and inspect the data; print how many samples per session.

# %%
# TODO: your code here

# %% [markdown]
# ## Step 2. Plot voltage vs time for one session (notice irregular spacing).

# %%
# TODO: your code here

# %% [markdown]
# ## Step 3. For each session, compute the mean, standard deviation, and standard error.

# %%
# TODO: your code here

# %% [markdown]
# ## Step 4. Plot standard error vs 1/√n — should be roughly linear.

# %%
# TODO: your code here

# %% [markdown]
# ## Interpretation (3-4 sentences)
#
# *(Write your paragraph here — what did you find? What worked, what did not?)*
