# %% [markdown]
# # Project 02 — Starter Notebook
#
# **Task:** Test whether an excitatory-inhibitory (E-I) neural population oscillates. Find the oscillation frequency using a power spectrum, and see how the frequency depends on the external drive.
#
# Fill in each section below. All required imports are already in the setup cell.

# %% [markdown]
# ## 0. Setup

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.signal import welch
from pathlib import Path

DATA = Path("../../shared/data")

# %% [markdown]
# ## Step 1. Load and look — plot one E and one I trace.

# %%
# TODO: your code here

# %% [markdown]
# ## Step 2. Compute the power spectrum of the E signal.

# %%
# TODO: your code here

# %% [markdown]
# ## Step 3. Find the peak frequency for every trial.

# %%
# TODO: your code here

# %% [markdown]
# ## Step 4. Plot mean peak frequency vs drive I_I.

# %%
# TODO: your code here

# %% [markdown]
# ## Interpretation (3-4 sentences)
#
# *(Write your paragraph here — what did you find? What worked, what did not?)*
