# %% [markdown]
# # Project 07 — Starter Notebook
#
# **Task:** Given 200 trials of an 8x8 sensor grid (64 channels), find which channels respond to the task condition and visualise the result on the grid.
#
# Fill in each section below. All required imports are already in the setup cell.

# %% [markdown]
# ## 0. Setup

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from scipy.stats import linregress

DATA = Path("../../shared/data")

# %% [markdown]
# ## Step 1. Load all three files and merge.

# %%
# TODO: your code here

# %% [markdown]
# ## Step 2. For each channel, fit a linear regression response ~ condition. Save the t-statistic.

# %%
# TODO: your code here

# %% [markdown]
# ## Step 3. Reshape the 64 t-stats into an 8x8 grid and plot a heatmap.

# %%
# TODO: your code here

# %% [markdown]
# ## Step 4. Mark channels with |t| > 2 as significant.

# %%
# TODO: your code here

# %% [markdown]
# ## Interpretation (3-4 sentences)
#
# *(Write your paragraph here — what did you find? What worked, what did not?)*
