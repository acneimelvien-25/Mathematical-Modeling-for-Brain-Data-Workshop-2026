# %% [markdown]
# # Project 05 — Starter Notebook
#
# **Task:** Given 1250 trials of spike times at 5 contrast levels, test whether spike counts follow a Poisson distribution or are overdispersed.
#
# Fill in each section below. All required imports are already in the setup cell.

# %% [markdown]
# ## 0. Setup

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

DATA = Path("../../shared/data")

# %% [markdown]
# ## Step 1. Load both files, print trials per contrast.

# %%
# TODO: your code here

# %% [markdown]
# ## Step 2. Count spikes per trial (trials with 0 spikes count as 0).

# %%
# TODO: your code here

# %% [markdown]
# ## Step 3. For each contrast, compute mean, variance, and Fano factor.

# %%
# TODO: your code here

# %% [markdown]
# ## Step 4. Plot Fano factor vs contrast; mark the Poisson baseline (F = 1).

# %%
# TODO: your code here

# %% [markdown]
# ## Interpretation (3-4 sentences)
#
# *(Write your paragraph here — what did you find? What worked, what did not?)*
