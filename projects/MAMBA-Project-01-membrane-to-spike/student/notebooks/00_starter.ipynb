# %% [markdown]
# # Project 01 — Starter Notebook
#
# **Task:** Fit a Leaky Integrate-and-Fire (LIF) model to voltage recordings of one neuron. Find its two main parameters (τ and R) and check whether the model predicts the firing rate at higher currents.
#
# Fill in each section below. All required imports are already in the setup cell.

# %% [markdown]
# ## 0. Setup

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from pathlib import Path

DATA = Path("../../shared/data")

# %% [markdown]
# ## Step 1. Load and look — plot one voltage trace per condition.

# %%
# TODO: your code here

# %% [markdown]
# ## Step 2. Fit τ and R from subthreshold data using curve_fit.

# %%
# TODO: your code here

# %% [markdown]
# ## Step 3. Predict firing rate from the fitted LIF parameters.

# %%
# TODO: your code here

# %% [markdown]
# ## Step 4. Compare predicted vs observed firing rates in one plot.

# %%
# TODO: your code here

# %% [markdown]
# ## Interpretation (3-4 sentences)
#
# *(Write your paragraph here — what did you find? What worked, what did not?)*
