# %% [markdown]
# # Project 03 — Starter Notebook
#
# **Task:** Given the responses of 80 neurons to a 2-D grid of visual stimuli, answer: how many dimensions does the neural code really use? Can we decode the stimulus back?
#
# Fill in each section below. All required imports are already in the setup cell.

# %% [markdown]
# ## 0. Setup

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn.decomposition import PCA
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

DATA = Path("../../shared/data")

# %% [markdown]
# ## Step 1. Load data, keep the fit trials for training and holdout for a final check.

# %%
# TODO: your code here

# %% [markdown]
# ## Step 2. Run PCA on the responses. How many components explain 80% variance?

# %%
# TODO: your code here

# %% [markdown]
# ## Step 3. Project data onto first 2 PCs and colour by stimulus feature.

# %%
# TODO: your code here

# %% [markdown]
# ## Step 4. Train a Ridge decoder to predict the stimulus; report test R².

# %%
# TODO: your code here

# %% [markdown]
# ## Interpretation (3-4 sentences)
#
# *(Write your paragraph here — what did you find? What worked, what did not?)*
